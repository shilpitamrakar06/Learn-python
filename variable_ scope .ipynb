# %%
## variable scope 

x = 10 # global scope 
def new(): 
    print(x)
    y = 10 # local scope
new()
print(y)
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4     y = 10
#       5 new()
# ----> 6 print(y)
#
# NameError: name 'y' is not defined

# %%
## same name ke variable me error
x = 10 
def new():
    print(x)
    x = 20
new()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[5], line 5
#       3     print(x)
#       4     x = 20
# ----> 5 new()
#
# Cell In[5], line 3, in new()
#       2 def new():
# ----> 3     print(x)
#       4     x = 20
#
# UnboundLocalError: cannot access local variable 'x' where it is not associated with a value

# %%
x = 10 
def new():
    print(x)
    y = 20
new()
# Out:
# 10

# %%
x = 10 
def new(): 
    x = 20 
    print(x)
new()
print(x)
# Out:
# 20
# 10

# %%
# local variable ko global me convert 
def new(): 
    global x
    x = 20 
    print(x)
new()
print(x)
# Out:
# 20
# 20

# %%
# modify global scope 
x = 10 
def new():
    global x 
    x = 50 
print(x)
new()
print(x)
# Out:
# 10
# 50

# %%
def new(): 
    x = 10 
    def new1(): 
        x = 20 
       # print(x)
    new1()
    print(x) 
new()
# Out:
# 10

# %%
y =  20  # global 
def new(): 
    x = 10 # local 
    def new1(): 
        nonlocal x 
        x = 20 # nonlocal 
       # print(x)
    new1()
    print(x) 
new()
# Out:
# 20

# %%
x =10 
def new(): 
    x = 20 
    print('local variable:' , x)
    print('global variable:',globals()['x'])
new()
# Out:
# local variable: 20
# global variable: 10
