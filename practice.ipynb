# %%
print("hello")
# Out:
# hello

# %%
# datatype
#1 string
x = 'python'
#pyhton function for string 
print(x)
print(type(x))
print(id(x))
print(len(x))
print(max(x))
print(min(x))

#method
x = 'PYthon'
print(x.lower())
print(x.upper())
print(x.title())
print(x.capitalize())
print(x.index('P'))
s = 'this is python'
print(s.find('is'))
print(s.replace('is','IS'))
print(s.startswith('t'))
print(s.endswith('o'))
print(s.split())
# Out:
# python
# <class 'str'>
# 2661293145760
# 6
# y
# h
# python
# PYTHON
# Python
# Python
# 0
# 2
# thIS IS python
# True
# False
# ['this', 'is', 'python']
