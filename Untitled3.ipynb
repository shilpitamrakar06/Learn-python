# %% [markdown]
# ##python tokens
# 1.keyword
# 2.punctuation
# 3.identifier
# 4.operators
# 5.literals

# %%
# keyword = can also said as pyhton grammer 
# two types of keyword  
# 1 keyword 
# 2 softkeyword 
#total  keyword "35" 
# total softkeyword "4"
# total number of keys "39" 
import keyword
all_keys = keyword.kwlist
print(all_keys) 
print(len(all_keys))

all_keys = keyword.softkwlist
print(all_keys)
print(len(all_keys))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35
# ['_', 'case', 'match', 'type']
# 4

# %%
# punctuation = these are special symbols used to structure , separate or modify pyhton code 
#1.() use to function cell, grouping expression , tuple 
#2.[] use  for list and indexing elements 
#3. {} use for  dict and set 
#4. : strat a block of code (after condition ,if ,loops)
#5. , seprate item list , tuple, arguments 

import string 
punc_key = string.punctuation 
print(punc_key)
print(len(punc_key))
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# 32

# %%
#identifiers = identifier is the name used to identify a variable, function, class, module, or other object in a program.abs
# rules for identifier 
#1. do not start with digit 
ex. 1 = 10 (worng)
#2. do not use space in identifier 
ex.   = 10 (worng) 
# 3. only one special symbol is used( _ ) underscore we cants ues special ssymbols like !,@,#,$ etc.
ex.  _ = 10 (right)
ex. @ = 10 (worng)
ex. $ = 10 (worng)
# 4. do not use keyword as identifier ( expected soft keyword) 
ex. if = 10 (worng)
ex. Ture = 10 (worng) 
ex. match = 10 (right) ,  match softkeyword 
# 5. always starts with alphabets 
ex. x = 10
#6.case sensitive
ex. x = 10 
    print(X) (worng)
    print(x) (right)
# Out:
#   Cell In[6], line 4
#     ex. 1 = 10 (worng)
#         ^
# SyntaxError: invalid syntax

# %%
# operators =
