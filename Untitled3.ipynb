# %% [markdown]
# ##python tokens
# 1.keyword
# 2.punctuation
# 3.identifier
# 4.operators
# 5.literals

# %%
# keyword = can also said as pyhton grammer 
# two types of keyword  
# 1 keyword 
# 2 softkeyword 
#total  keyword "35" 
# total softkeyword "4"
# total number of keys "39" 
import keyword
all_keys = keyword.kwlist
print(all_keys) 
print(len(all_keys))

all_keys = keyword.softkwlist
print(all_keys)
print(len(all_keys))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35
# ['_', 'case', 'match', 'type']
# 4

# %%
import string 
punc_key = string.punctuation 
print(punc_key)
print(len(punc_key))
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# 32
